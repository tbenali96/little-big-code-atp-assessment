# %%
import pandas as pd 
import math
import numpy as np 
import seaborn as sns 
import plotly.express as px


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv("../data/raw/ATP_tweaked.csv", sep=";")
data.head()
# Out:
#    best_of  p2_1stIn  p2_1stWon  p2_2ndWon  p2_SvGms  p2_ace  p2_bpFaced  \
# 0        3      66.0       47.0       26.0      15.0     9.0         9.0
# 1        3      45.0       33.0       21.0      13.0     6.0         9.0
# 2        5      54.0       38.0       21.0      18.0     3.0         4.0
# 3        3      46.0       35.0       17.0      14.0     2.0         2.0
# 4        3      42.0       33.0       13.0      11.0    10.0         1.0
#
#    p2_bpSaved  p2_df  p2_svpt  p2_age p2_entry p2_hand  p2_ht   p2_id p2_ioc  \
# 0         8.0    6.0    112.0   31.75      NaN       L  188.0  104269    ESP
# 1         6.0    5.0     87.0   30.97      NaN       R  183.0  104571    CYP
# 2         0.0    3.0     92.0   26.11      NaN       L  183.0  105385    USA
# 3         0.0    3.0     72.0   28.71      NaN       L  185.0  104745    ESP
# 4         0.0    1.0     68.0   27.46      NaN       R  190.0  104997    NED
#
#              p2_name  p2_rank  p2_rank_points  p2_seed  match_num  minutes  \
# 0  Fernando Verdasco     43.0           995.0      NaN          2      NaN
# 1   Marcos Baghdatis     41.0          1060.0      NaN        275    101.0
# 2       Donald Young     68.0           730.0      NaN        117      NaN
# 3       Rafael Nadal      3.0          5745.0      1.0         25    125.0
# 4      Igor Sijsling    100.0           556.0      NaN         12     82.0
#
#   round            score surface  tourney_date tourney_id tourney_level  \
# 0   R64      4-6 6-3 6-4    Hard      20150816   2015-422             M
# 1   R32      4-6 6-1 6-4   Grass      20160606  2016-0321             A
# 2   R16  6-4 1-6 6-3 6-4    Hard      20150831   2015-560             G
# 3    QF      4-6 7-5 6-0    Clay      20150216  2015-6932             A
# 4   R32          6-4 7-5    Hard      20150202  2015-2276             A
#
#          tourney_name  p1_1stIn  p1_1stWon  p1_2ndWon  p1_SvGms  p1_ace  \
# 0  Cincinnati Masters      49.0       39.0       22.0      14.0    14.0
# 1           Stuttgart      51.0       38.0       21.0      14.0     7.0
# 2             US Open      53.0       43.0       26.0      18.0    10.0
# 3      Rio de Janeiro      41.0       27.0       20.0      14.0     6.0
# 4              Zagreb      50.0       34.0       13.0      11.0     9.0
#
#    p1_bpFaced  p1_bpSaved  p1_df  p1_svpt  p1_age p1_entry p1_hand  p1_ht  \
# 0         7.0         5.0    7.0     95.0   30.33      NaN       R  188.0
# 1         3.0         2.0    2.0     84.0   26.12      NaN       R    NaN
# 2         6.0         3.0    3.0    102.0   30.43      NaN       R  183.0
# 3        12.0         7.0    3.0     82.0   29.13      NaN       R  180.0
# 4         8.0         5.0    4.0     77.0   30.35        Q       R  185.0
#
#     p1_id p1_ioc             p1_name  p1_rank  p1_rank_points  p1_seed  p1_won
# 0  104542    FRA  Jo Wilfried Tsonga     19.0          1645.0      NaN       0
# 1  105526    GER  Jan Lennard Struff     89.0           650.0      NaN       1
# 2  104527    SUI  Stanislas Wawrinka      5.0          5710.0      5.0       1
# 3  104655    URU        Pablo Cuevas     23.0          1447.0      6.0       0
# 4  104433    CAN      Frank Dancevic    156.0           326.0      NaN       0
